# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# CSV IMPORTATION *******************
# all of these files have a row of column headers and an index colum
# header=0, index_col=0 will handle this quickly and easily

#life expectancy
filename = 'cms_reports/hha-hhrg-by-state-aggregate-report-cy-2015.csv'
df = pd.read_csv(filename, header=0)

# %%
df
# Out:
#       HHRG                                   HHRG Description State  \
# 0     1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AK
# 1     1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AL
# 2     1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AR
# 3     1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AZ
# 4     1AFK  Early Episode, 0-13 therapies,Clinical Severit...    CA
# ...    ...                                                ...   ...
# 7096  5CHK  Early or Late Episode, 20+ therapies,Clinical ...    VT
# 7097  5CHK  Early or Late Episode, 20+ therapies,Clinical ...    WA
# 7098  5CHK  Early or Late Episode, 20+ therapies,Clinical ...    WI
# 7099  5CHK  Early or Late Episode, 20+ therapies,Clinical ...    WV
# 7100  5CHK  Early or Late Episode, 20+ therapies,Clinical ...    WY
#
#       Total Episodes  Distinct Beneficiaries  Average HHA Charge Amount  \
# 0                 42                      40                       2476
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   HHRG                                          7101 non-null   object
#  1   HHRG Description                              7101 non-null   object
#  2   State                                         7101 non-null   object
#  3   Total Episodes                                7101 non-null   int64
#  4   Distinct Beneficiaries                        7101 non-null   int64
#  5   Average HHA Charge Amount                     7101 non-null   int64
#  6   Average HHA Medicare Payment Amount           7101 non-null   int64
#  7   Average HHA Medicare Standard Payment Amount  7101 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 443.9+ KB

# %%
print(df.loc[:,'HHRG Description'].unique())
# Out:
# ['Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 1,Service Severity Level 1'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 1,Service Severity Level 2'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 1,Service Severity Level 3'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 1,Service Severity Level 4'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 1,Service Severity Level 5'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 2,Service Severity Level 1'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 2,Service Severity Level 2'
#  'Early Episode, 0-13 therapies,Clinical Severity Level 1, Functional Severity Level 2,Service Severity Level 3'
# ...

# %%
df.groupby('HHRG Description').sum()
# Out:
#                                                     Total Episodes  \
# HHRG Description
# Early Episode, 0-13 therapies,Clinical Severity...           88712
# Early Episode, 0-13 therapies,Clinical Severity...            7439
# Early Episode, 0-13 therapies,Clinical Severity...           18770
# Early Episode, 0-13 therapies,Clinical Severity...            4514
# Early Episode, 0-13 therapies,Clinical Severity...           11759
# ...                                                            ...
# Late Episode, 14-19 therapies,Clinical Severity...           11141
# Late Episode, 14-19 therapies,Clinical Severity...            5482
# Late Episode, 14-19 therapies,Clinical Severity...            7783
# Late Episode, 14-19 therapies,Clinical Severity...            7573
# Late Episode, 14-19 therapies,Clinical Severity...            3964
#
#                                                     Distinct Beneficiaries  \
# HHRG Description
# ...

# %%
df.rename(columns={'HHRG': 'hhrg',
                   'HHRG Description': 'hhrg_desc', 
                   'State': 'state',
                   'Total Episodes': 'total_ep',
                   'Distinct Beneficiaries': 'unique_ben',
                   'Average HHA Charge Amount': 'avg_chrg',
                   'Average HHA Medicare Payment Amount': 'avg_pmt',
                   'Average HHA Medicare Standard Payment Amount': 'avg_std_pmt'},
                    inplace=True)
df.head()
# Out:
#    hhrg                                          hhrg_desc state  total_ep  \
# 0  1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AK        42
# 1  1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AL      1304
# 2  1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AR       850
# 3  1AFK  Early Episode, 0-13 therapies,Clinical Severit...    AZ      1297
# 4  1AFK  Early Episode, 0-13 therapies,Clinical Severit...    CA      9216
#
#    unique_ben  avg_chrg  avg_pmt  avg_std_pmt
# 0          40      2476     2136         1762
# 1        1230      1529     1415         1765
# 2         800      1841     1487         1785
# 3        1242      1714     1774         1772
# 4        8648      1976     2243         1780

# %%
def split_hhrg(df):
    df
